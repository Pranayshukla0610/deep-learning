# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/deep-learning/blob/main/Image_Classification_using_CNN_Architectures_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train = X_train/255.0
X_test = X_test/255.0
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, AveragePooling2D, Flatten, Conv2D

lenet = Sequential([
    Conv2D(6, kernel_size=5, activation='relu', input_shape=(32,32,3)),
    AveragePooling2D(pool_size=(2,2)),
    Conv2D(16, kernel_size=5, activation='relu'),
    AveragePooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(120, activation='relu'),
    Dense(84, activation='relu'),
    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.layers import MaxPooling2D, Dropout
alexnet = Sequential([
    Conv2D(96, 3, activation='relu', input_shape=(32,32,3)),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(256, 3, activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# %%
from tensorflow.keras.applications import VGG16
vgg = VGG16(
    weights=None,
    input_shape=(32,32,3),
    classes=10
)

# %%
from tensorflow.keras.applications import ResNet50
resnet = ResNet50(
    weights=None,
    input_shape=(32,32,3),
    classes=10
)

# %%
from tensorflow.keras.applications import InceptionV3
inception = InceptionV3(
    weights=None,
    input_shape=(75,75,3),
    classes=10
)

# %%
from tensorflow.keras.applications import EfficientNetB0
efficientnet = EfficientNetB0(
    weights=None,
    input_shape=(224,224,3),
    classes=10
)

# %%
lenet.compile(
    optimizer='adam',
    loss = 'sparse_categorical_crossentropy',
    metrics=['accuracy']
)

lenet.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=10,
    batch_size=64
)
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 47ms/step - accuracy: 0.2965 - loss: 1.9064 - val_accuracy: 0.4666 - val_loss: 1.4975
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.4653 - loss: 1.4862 - val_accuracy: 0.4863 - val_loss: 1.4194
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.5093 - loss: 1.3667 - val_accuracy: 0.5193 - val_loss: 1.3353
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 45ms/step - accuracy: 0.5452 - loss: 1.2723 - val_accuracy: 0.5416 - val_loss: 1.2735
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.5678 - loss: 1.2143 - val_accuracy: 0.5663 - val_loss: 1.2063
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.5950 - loss: 1.1437 - val_accuracy: 0.5721 - val_loss: 1.2119
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.6100 - loss: 1.1031 - val_accuracy: 0.5829 - val_loss: 1.1739
# Epoch 8/10
# ...
